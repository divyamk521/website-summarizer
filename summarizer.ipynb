# %%
import requests
from bs4 import BeautifulSoup
import ollama
from IPython.display import Markdown, display

# %%
def get_website_text(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    for tag in soup(["script", "style", "nav", "footer"]):
        tag.decompose()
    text = soup.get_text(separator="\n", strip=True)
    return text[:2000]

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
def summarize(url):
    print(f"Fetching: {url}\n")
    website = get_website_text(url)
    response = ollama.chat(
        model="tinyllama",
        # 
        messages = messages_for(website)

    )
    print(response["message"]["content"])

# %%
summarize("https://edwarddonner.com")
# Out:
# Fetching: https://edwarddonner.com
#
# Sure, here's the summary of the website:
#
# Home - Edward Donner
# Welcome to my world! I’m Ed, and I like writing code and experimenting with LLMs (Artificial Intelligence) to improve our lives. I also enjoy lost myself in the hacker community, nodding my head sagely to things I only half understand. My latest project is a platform for discovering one's potential and pursuing it – a field where AI can make a big impact. I’m the co-founder and CTO of Nebula.io, which helps people find their reason for being with AI. I will happily discuss LLMs to anyone in my vicinity. My friends convinced me to make courses on Udemy, and I've become a bestselling series. The full curriculum is available here. If you're visiting from one of my courses – I'm super grateful! The resource page includes tutorials for building AI coders and n8n agents, as well as resources to deploy AI in production. The website also features the latest news and announcements, so stay tuned. Finally, please feel free to get in touch or follow me on LinkedIn, Twitter, Facebook, and more!

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# Fetching: https://edwarddonner.com
#
# Home - Edward Donner
# Welcome to my website! Here, I'll provide you with a quick summary of the news and announcements that are relevant to my niche: AI coding and AI-related topics. If you want to learn more about AI itself or explore various AI-related technologies, you can start here:
# - LLMs (Language Modeling)
# - Voice assistants/AI agents
# - Text-to-speech (TTS) engines
# - Natural Language Processing (NLP) and Machine Translation (MT)
# My website is a platform where I share my knowledge, experience, and insights on these topics. I love experimenting with new technologies and sharing my discoveries with others who may be interested in learning too. So if you have any questions or want to learn more about AI, feel free to reach out! You can find me on LinkedIn, Twitter, Facebook, and more, and follow me for updates. As always, stay safe and healthy!
